# %% [markdown]
# # Analysing the orders data and forecasting

# %% [markdown]
# One of the objectives of this tutorial is learning more about ploty
#
# Sources for the toturials that I used: https://www.youtube.com/watch?v=GGL6U0k8WYA
# This is a good cheat sheet that you can use: https://images.plot.ly/plotly-documentation/images/plotly_js_cheat_sheet.pdf

# %%
# %store -r orders_data , region_time_series

# %%
import pandas as pd
import numpy as np
import chart_studio.plotly as py
import cufflinks as cf
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %% [markdown]
# Line plot:

# %%
sales = orders_data["Mean prod value"]
sales.iplot()
# Out:
# <div>                            <div id="78b00ed0-f1bc-4ac0-aa9a-2f298b4ae03e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
import plotly.graph_objects as go

px.line(total_revenue, labels = {"x":"Date", "y":"Total revenue"})
px.line(total_sales, labels = {"x":"Date", "y":"Products sold"})
# Out:
# <div>                            <div id="f358eed5-65a4-490d-aa9e-488b54472bfd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f358eed5-65a4-490d-aa9e-488b54472bfd")) {                    Plotly.newPlot(                        "f358eed5-65a4-490d-aa9e-488b54472bfd",                        [{"hovertemplate": "variable=Products<br>Order Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Products", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Products", "showlegend": true, "type": "scattergl", "x": ["2015-01-02T00:00:00", "2015-01-03T00:00:00", "2015-01-04T00:00:00", "2015-01-06T00:00:00", "2015-01-07T00:00:00", "2015-01-08T00:00:00", "2015-01-09T00:00:00", "2015-01-10T00:00:00", "2015-01-11T00:00:00", "2015-01-12T00:
# ...

# %% [markdown]
# To erase
# Analysis:
# -describe
# -group by day
